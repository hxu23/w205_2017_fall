# %%
import os, sys
sys.path.append('/data/spark15/python/')

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = (18, 9)
import seaborn as sb
import numpy as np
import pandas as pd

from pyspark import SparkContext
from pyspark.sql import SQLContext
from pyspark.sql import HiveContext
from pyspark.sql.types import *
import pyspark.sql.functions

sc = SparkContext("local", "hospital_compare")
sqlContext = SQLContext(sc)
hc = HiveContext(sc)

# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %%
print(hc.tableNames())
# Out:
# [u'effective_care', u'effective_care_scores', u'hospitals', u'hospitals_reduced', u'measures', u'readmissions', u'readmissions_reduced', u'survey_responses']

# %% [markdown]
# ## Introduction
#
# We are asked with the task of analyzing the data sets provided The Center for Medicare and Medicaid Services in their Hospital Compare Download Database. Our goal is to answer the following four questions
#
# 1. What hospitals are models of high-quality care? That is, which hospitals have the most consistently high scores for a variety of procedures.
# 2. What states are models of high-quality care?
# 3. Which procedures have the greatest variability between hospitals?
# 4. Are average scores for hospital quality or procedural variability correlated with patient survey responses
#
# In the first few steps of our exercise, we downloaded the following four tables and saved to Hive
#
# - __Hospitals__:        General information for each hospital in the Compare database
# - __Measures__:         Current collection dates for all measures on Hospital Compare
# - __Readmissions__:     Veterans Health Administration hospital-level data for mortality and readmissions measures
# - __Survey_Responses__: Survey results for hospitals in Compare database
# - __Effective Care__:   Hospital-level results on patient experience domain measures for Hospital Value-Based Purchasing
#
#
# #### We will use this notebook as an initial exploration of the data provided to us to help better formulate our transformations and final tables for our analysis.

# %% [markdown]
# ### Examining Each Table

# %%
hospitals = hc.sql('select * from hospitals').toPandas()
measures = hc.sql('select * from measures').toPandas()
readmissions = hc.sql('select * from readmissions').toPandas()
survey_responses = hc.sql('select * from survey_responses').toPandas()
effective_care = hc.sql('select * from effective_care').toPandas()

# %%
hospitals.head().T
# Out:
#                                                                                               0  \
# provider_id                                                                              010001
# hospital_name                                                  SOUTHEAST ALABAMA MEDICAL CENTER
# address                                                                  1108 ROSS CLARK CIRCLE
# city                                                                                     DOTHAN
# state                                                                                        AL
# zip_code                                                                                  36301
# county_name                                                                             HOUSTON
# phone_number                                                                         3347938701
# hospital_type                                                              Acute Care Hospitals
# hospital_ownership                                  Government - Hospital District or Authority
# emergency_services                                                                          Yes
# meets_criteria                                                                                Y
# hospital_overall_rating                                                                       3
# hospital_overall_footenote
# mortality_national_compare                                         Same as the national average
# mortality_national_compare_footnote
# safety_of_care_national_comparison                                   Above the national average
# safety_of_care_national_comparison_footenote
# readmission_national_comparison                                    Same as the national average
# readmission_national_comparison_footnote
# patient_experience_national_comparison                               Below the national average
# patient_experience_national_comparison_footenote
# effectiveness_of_care_national_comparison                          Same as the national average
# effectiveness_of_care_national_comparison_footnote
# timeliness_of_care_national_comparison                             Same as the national average
# timeliness_of_care_national_comparison_footnote
# efficient_use_of_medical_imaging_national_compa...                 Same as the national average
# efficient_use_of_medical_imaging_national_compa...
#
#                                                                                               1  \
# provider_id                                                                              010005
# hospital_name                                                     MARSHALL MEDICAL CENTER SOUTH
# address                                                              2505 U S HIGHWAY 431 NORTH
# city                                                                                       BOAZ
# state                                                                                        AL
# zip_code                                                                                  35957
# county_name                                                                            MARSHALL
# phone_number                                                                         2565938310
# hospital_type                                                              Acute Care Hospitals
# hospital_ownership                                  Government - Hospital District or Authority
# emergency_services                                                                          Yes
# meets_criteria                                                                                Y
# hospital_overall_rating                                                                       3
# hospital_overall_footenote
# mortality_national_compare                                           Below the national average
# mortality_national_compare_footnote
# safety_of_care_national_comparison                                 Same as the national average
# safety_of_care_national_comparison_footenote
# readmission_national_comparison                                      Above the national average
# readmission_national_comparison_footnote
# patient_experience_national_comparison                             Same as the national average
# patient_experience_national_comparison_footenote
# effectiveness_of_care_national_comparison                          Same as the national average
# effectiveness_of_care_national_comparison_footnote
# timeliness_of_care_national_comparison                               Above the national average
# timeliness_of_care_national_comparison_footnote
# efficient_use_of_medical_imaging_national_compa...                   Below the national average
# efficient_use_of_medical_imaging_national_compa...
#
#                                                                                               2  \
# provider_id                                                                              010006
# hospital_name                                                    ELIZA COFFEE MEMORIAL HOSPITAL
# address                                                                      205 MARENGO STREET
# city                                                                                   FLORENCE
# state                                                                                        AL
# zip_code                                                                                  35631
# county_name                                                                          LAUDERDALE
# phone_number                                                                         2567688400
# hospital_type                                                              Acute Care Hospitals
# hospital_ownership                                  Government - Hospital District or Authority
# emergency_services                                                                          Yes
# meets_criteria                                                                                Y
# hospital_overall_rating                                                                       2
# hospital_overall_footenote
# mortality_national_compare                                           Below the national average
# mortality_national_compare_footnote
# safety_of_care_national_comparison                                 Same as the national average
# safety_of_care_national_comparison_footenote
# readmission_national_comparison                                    Same as the national average
# readmission_national_comparison_footnote
# patient_experience_national_comparison                               Below the national average
# patient_experience_national_comparison_footenote
# effectiveness_of_care_national_comparison                          Same as the national average
# effectiveness_of_care_national_comparison_footnote
# timeliness_of_care_national_comparison                               Above the national average
# timeliness_of_care_national_comparison_footnote
# efficient_use_of_medical_imaging_national_compa...                 Same as the national average
# efficient_use_of_medical_imaging_national_compa...
#
#                                                                                                     3  \
# provider_id                                                                                    010007
# hospital_name                                                                MIZELL MEMORIAL HOSPITAL
# address                                                                                 702 N MAIN ST
# city                                                                                              OPP
# state                                                                                              AL
# zip_code                                                                                        36467
# county_name                                                                                 COVINGTON
# phone_number                                                                               3344933541
# hospital_type                                                                    Acute Care Hospitals
# hospital_ownership                                                     Voluntary non-profit - Private
# emergency_services                                                                                Yes
# meets_criteria                                                                                      Y
# hospital_overall_rating                                                                             2
# hospital_overall_footenote
# mortality_national_compare                                               Same as the national average
# mortality_national_compare_footnote
# safety_of_care_national_comparison                                                      Not Available
# safety_of_care_national_comparison_footenote        Results are not available for this reporting p...
# readmission_national_comparison                                            Below the national average
# readmission_national_comparison_footnote
# patient_experience_national_comparison                                   Same as the national average
# patient_experience_national_comparison_footenote
# effectiveness_of_care_national_comparison                                  Below the national average
# effectiveness_of_care_national_comparison_footnote
# timeliness_of_care_national_comparison                                     Above the national average
# timeliness_of_care_national_comparison_footnote
# efficient_use_of_medical_imaging_national_compa...                                      Not Available
# efficient_use_of_medical_imaging_national_compa...  Results are not available for this reporting p...
#
#                                                                                                     4
# provider_id                                                                                    010008
# hospital_name                                                             CRENSHAW COMMUNITY HOSPITAL
# address                                                                           101 HOSPITAL CIRCLE
# city                                                                                          LUVERNE
# state                                                                                              AL
# zip_code                                                                                        36049
# county_name                                                                                  CRENSHAW
# phone_number                                                                               3343353374
# hospital_type                                                                    Acute Care Hospitals
# hospital_ownership                                                                        Proprietary
# emergency_services                                                                                Yes
# meets_criteria                                                                                      Y
# hospital_overall_rating                                                                             3
# hospital_overall_footenote
# mortality_national_compare                                               Same as the national average
# mortality_national_compare_footnote
# safety_of_care_national_comparison                                                      Not Available
# safety_of_care_national_comparison_footenote        Results are not available for this reporting p...
# readmission_national_comparison                                          Same as the national average
# readmission_national_comparison_footnote
# patient_experience_national_comparison                                                  Not Available
# patient_experience_national_comparison_footenote    Results are not available for this reporting p...
# effectiveness_of_care_national_comparison                                Same as the national average
# effectiveness_of_care_national_comparison_footnote
# timeliness_of_care_national_comparison                                     Above the national average
# timeliness_of_care_national_comparison_footnote
# efficient_use_of_medical_imaging_national_compa...                                      Not Available
# efficient_use_of_medical_imaging_national_compa...  Results are not available for this reporting p...

# %%
measures.T
# Out:
#                                           0    \
# measure_name           ACS Participation data
# measure_id                       ACS_REGISTRY
# measure_start_quarter                  4Q2015
# measure_start_date                 10/01/2015
# measure_end_quarter                    3Q2016
# measure_end_date                   09/30/2016
#
#                                                                      1    \
# measure_name           Fibrinolytic Therapy Received Within 30 Minute...
# measure_id                                          AMI_7a_HVBP_Baseline
# measure_start_quarter                                             1Q2013
# measure_start_date                                            01/01/2013
# measure_end_quarter                                               4Q2013
# measure_end_date                                              12/31/2013
#
#                                                                      2    \
# measure_name           Fibrinolytic Therapy Received Within 30 Minute...
# measure_id                                       AMI_7a_HVBP_Performance
# measure_start_quarter                                             1Q2015
# measure_start_date                                            01/01/2015
# measure_end_quarter                                               4Q2015
# measure_end_date                                              12/31/2015
#
#                                               3    \
# measure_name                         Combined SSI
# measure_id             Combined_SSI_Measure_Score
# measure_start_quarter                      1Q2013
# measure_start_date                     01/01/2013
# measure_end_quarter                        4Q2013
# measure_end_date                       12/31/2013
#
#                                                                4    \
# measure_name                                          Combined SSI
# measure_id             Combined_SSI_Measure_Score_HVBP_Performance
# measure_start_quarter                                       1Q2015
# measure_start_date                                      01/01/2015
# measure_end_quarter                                         4Q2015
# measure_end_date                                        12/31/2015
#
#                                                                      5    \
# measure_name           Complication Rate Following Elective Primary T...
# measure_id                                                 COMP_HIP_KNEE
# measure_start_quarter                                             2Q2013
# measure_start_date                                            04/01/2013
# measure_end_quarter                                               1Q2016
# measure_end_date                                              03/31/2016
#
#                                              6                           7    \
# measure_name           Communication with Nurses  Communication with Doctors
# measure_id                  Composite 1 Q1 to Q3        Composite 2 Q5 to Q7
# measure_start_quarter                     1Q2016                      1Q2016
# measure_start_date                    01/01/2016                  01/01/2016
# measure_end_quarter                       4Q2016                      4Q2016
# measure_end_date                      12/31/2016                  12/31/2016
#
#                                                     8    \
# measure_name           Responsiveness of Hospital Staff
# measure_id                         Composite 3 Q4 & Q11
# measure_start_quarter                            1Q2016
# measure_start_date                           01/01/2016
# measure_end_quarter                              4Q2016
# measure_end_date                             12/31/2016
#
#                                          9    \
# measure_name                 Pain Management
# measure_id             Composite 4 Q13 & Q14
# measure_start_quarter                 1Q2016
# measure_start_date                01/01/2016
# measure_end_quarter                   4Q2016
# measure_end_date                  12/31/2016
#
#                                              ...                          \
# measure_name                                 ...
# measure_id                                   ...
# measure_start_quarter                        ...
# measure_start_date                           ...
# measure_end_quarter                          ...
# measure_end_date                             ...
#
#                                                                      153  \
# measure_name           Participation in a Systematic Clinical Databas...
# measure_id                                                 SM_PART_NURSE
# measure_start_quarter                                             1Q2015
# measure_start_date                                            01/01/2015
# measure_end_quarter                                               4Q2015
# measure_end_date                                              12/31/2015
#
#                                               154                  155  \
# measure_name           HCAHPS Summary Star Rating  Overall Star Rating
# measure_id                            Star Rating          Star Rating
# measure_start_quarter                      1Q2016               1Q2016
# measure_start_date                     01/01/2016           01/01/2016
# measure_end_quarter                        4Q2016               4Q2016
# measure_end_date                       12/31/2016           12/31/2016
#
#                                         156                    157  \
# measure_name           Thrombolytic Therapy  Alcohol Use Screening
# measure_id                            STK_4                  SUB_1
# measure_start_quarter                1Q2016                 1Q2015
# measure_start_date               01/01/2016             01/01/2015
# measure_end_quarter                  4Q2016                 4Q2015
# measure_end_date                 12/31/2016             12/31/2015
#
#                                          158  \
# measure_name           Tobacco Use Screening
# measure_id                             TOB_1
# measure_start_quarter                 1Q2015
# measure_start_date                01/01/2015
# measure_end_quarter                   4Q2015
# measure_end_date                  12/31/2015
#
#                                                              159  \
# measure_name           Tobacco Use Treatment Provided or Offered
# measure_id                                                 TOB_2
# measure_start_quarter                                     1Q2015
# measure_start_date                                    01/01/2015
# measure_end_quarter                                       4Q2015
# measure_end_date                                      12/31/2015
#
#                                                                     160  \
# measure_name           Tobacco Use Treatment (during the hospital stay)
# measure_id                                                       TOB_2a
# measure_start_quarter                                            1Q2015
# measure_start_date                                           01/01/2015
# measure_end_quarter                                              4Q2015
# measure_end_date                                             12/31/2015
#
#                                                                      161  \
# measure_name           Venous Thromboembolism Warfarin Therapy Discha...
# measure_id                                                         VTE_5
# measure_start_quarter                                             1Q2016
# measure_start_date                                            01/01/2016
# measure_end_quarter                                               4Q2016
# measure_end_date                                              12/31/2016
#
#                                                                      162
# measure_name           Hospital Acquired Potentially-Preventable Veno...
# measure_id                                                         VTE_6
# measure_start_quarter                                             1Q2016
# measure_start_date                                            01/01/2016
# measure_end_quarter                                               4Q2016
# measure_end_date                                              12/31/2016
#
# [6 rows x 163 columns]

# %%
readmissions.head().T
# Out:
#                                                                      0  \
# provider_id                                                     01014F
# hospital_name                             BIRMINGHAM VA MEDICAL CENTER
# address                                          700 SOUTH 19TH STREET
# city                                                        BIRMINGHAM
# state                                                               AL
# zip_code                                                         35233
# county_name                                                  JEFFERSON
# measure_name         Acute Myocardial Infarction (AMI) 30-Day Morta...
# measure_id                                                 MORT-30-AMI
# vha_national_rate                                                 9.21
# compare_to_national            No different than the VHA National Rate
# denominator                                                        134
# score                                                             9.68
# lower_estimate                                                    7.35
# higher_estimate                                                  12.84
# footnote
# measure_start_date                                           10/1/2012
# measure_end_date                                             9/30/2015
#
#                                                                      1  \
# provider_id                                                     01014F
# hospital_name                             BIRMINGHAM VA MEDICAL CENTER
# address                                          700 SOUTH 19TH STREET
# city                                                        BIRMINGHAM
# state                                                               AL
# zip_code                                                         35233
# county_name                                                  JEFFERSON
# measure_name         Death rate for chronic obstructive pulmonary d...
# measure_id                                                MORT-30-COPD
# vha_national_rate                                                 5.99
# compare_to_national            No different than the VHA National Rate
# denominator                                                        296
# score                                                             7.85
# lower_estimate                                                     5.7
# higher_estimate                                                  11.29
# footnote
# measure_start_date                                           10/1/2012
# measure_end_date                                             9/30/2015
#
#                                                             2  \
# provider_id                                            01014F
# hospital_name                    BIRMINGHAM VA MEDICAL CENTER
# address                                 700 SOUTH 19TH STREET
# city                                               BIRMINGHAM
# state                                                      AL
# zip_code                                                35233
# county_name                                         JEFFERSON
# measure_name         Heart failure (HF) 30-Day Mortality Rate
# measure_id                                         MORT-30-HF
# vha_national_rate                                        7.72
# compare_to_national   No different than the VHA National Rate
# denominator                                               389
# score                                                    6.89
# lower_estimate                                           5.17
# higher_estimate                                           9.3
# footnote
# measure_start_date                                  10/1/2012
# measure_end_date                                    9/30/2015
#
#                                                            3  \
# provider_id                                           01014F
# hospital_name                   BIRMINGHAM VA MEDICAL CENTER
# address                                700 SOUTH 19TH STREET
# city                                              BIRMINGHAM
# state                                                     AL
# zip_code                                               35233
# county_name                                        JEFFERSON
# measure_name            Pneumonia (PN) 30-Day Mortality Rate
# measure_id                                        MORT-30-PN
# vha_national_rate                                       8.64
# compare_to_national  No different than the VHA National Rate
# denominator                                              148
# score                                                   9.17
# lower_estimate                                          7.01
# higher_estimate                                        11.98
# footnote
# measure_start_date                                 10/1/2012
# measure_end_date                                   9/30/2015
#
#                                                                      4
# provider_id                                                     01014F
# hospital_name                             BIRMINGHAM VA MEDICAL CENTER
# address                                          700 SOUTH 19TH STREET
# city                                                        BIRMINGHAM
# state                                                               AL
# zip_code                                                         35233
# county_name                                                  JEFFERSON
# measure_name         Acute Myocardial Infarction (AMI) 30-Day Readm...
# measure_id                                                READM-30-AMI
# vha_national_rate                                                15.57
# compare_to_national            No different than the VHA National Rate
# denominator                                                        119
# score                                                            15.17
# lower_estimate                                                   12.45
# higher_estimate                                                  18.03
# footnote
# measure_start_date                                           10/1/2012
# measure_end_date                                             9/30/2015

# %%
effective_care.head().T
# Out:
#                                                                     0  \
# provider_id                                                    010001
# hospital_name                        SOUTHEAST ALABAMA MEDICAL CENTER
# address                                        1108 ROSS CLARK CIRCLE
# city                                                           DOTHAN
# state                                                              AL
# zip_code                                                        36301
# county_name                                                   HOUSTON
# phone_number                                               3347938701
# condition                                        Emergency Department
# measure_id                                                      ED_1b
# measure_name                                                      ED1
# score                                                             286
# sample                                                            569
# footnote            2 - Data submitted were based on a sample of c...
# measure_start_date                                         01/01/2016
# measure_end_date                                           12/31/2016
#
#                                                                     1  \
# provider_id                                                    010001
# hospital_name                        SOUTHEAST ALABAMA MEDICAL CENTER
# address                                        1108 ROSS CLARK CIRCLE
# city                                                           DOTHAN
# state                                                              AL
# zip_code                                                        36301
# county_name                                                   HOUSTON
# phone_number                                               3347938701
# condition                                        Emergency Department
# measure_id                                                      ED_2b
# measure_name                                                      ED2
# score                                                              99
# sample                                                            569
# footnote            2 - Data submitted were based on a sample of c...
# measure_start_date                                         01/01/2016
# measure_end_date                                           12/31/2016
#
#                                                            2  \
# provider_id                                           010001
# hospital_name               SOUTHEAST ALABAMA MEDICAL CENTER
# address                               1108 ROSS CLARK CIRCLE
# city                                                  DOTHAN
# state                                                     AL
# zip_code                                               36301
# county_name                                          HOUSTON
# phone_number                                      3347938701
# condition                               Emergency Department
# measure_id                                               EDV
# measure_name                     Emergency department volume
# score               High (40,000 - 59,999 patients annually)
# sample
# footnote
# measure_start_date                                01/01/2015
# measure_end_date                                  12/31/2015
#
#                                                                     3  \
# provider_id                                                    010001
# hospital_name                        SOUTHEAST ALABAMA MEDICAL CENTER
# address                                        1108 ROSS CLARK CIRCLE
# city                                                           DOTHAN
# state                                                              AL
# zip_code                                                        36301
# county_name                                                   HOUSTON
# phone_number                                               3347938701
# condition                                             Preventive Care
# measure_id                                                      IMM_2
# measure_name                               Immunization for influenza
# score                                                              95
# sample                                                            554
# footnote            2 - Data submitted were based on a sample of c...
# measure_start_date                                         10/01/2015
# measure_end_date                                           03/31/2016
#
#                                                                  4
# provider_id                                                 010001
# hospital_name                     SOUTHEAST ALABAMA MEDICAL CENTER
# address                                     1108 ROSS CLARK CIRCLE
# city                                                        DOTHAN
# state                                                           AL
# zip_code                                                     36301
# county_name                                                HOUSTON
# phone_number                                            3347938701
# condition                                          Preventive Care
# measure_id                                  IMM_3_OP_27_FAC_ADHPCT
# measure_name        Healthcare workers given influenza vaccination
# score                                                           86
# sample                                                        4457
# footnote
# measure_start_date                                      10/01/2016
# measure_end_date                                        03/31/2017

# %%
survey_responses.head().T
# Out:
#                                                                           0  \
# provider_number                                                      450097
# hospital_name                                       BAYSHORE MEDICAL CENTER
# address                                                    4000 SPENCER HWY
# city                                                               Pasadena
# state                                                                    TX
# zip_code                                                              77504
# county_name                                                          HARRIS
# communication_with_nurses_floor                                       58.14
# communication_with_nurses_achievement_threshold                       78.19
# communication_with_nurses_benchmark                                   86.61
# communication_with_nurses_baseline_rate                               72.10
# communication_with_nurses_performance_rate                            71.76
# communication_with_nurses_achievement_points                    0 out of 10
# communication_with_nurses_improvement_points                     0 out of 9
# communication_with_nurses_dimension_score                       0 out of 10
# communication_with_doctors_floor                                      63.58
# communication_with_doctors_achievement_threshold                      80.51
# communication_with_doctors_benchmark                                  88.80
# communication_with_doctors_baseline_rate                              75.99
# communication_with_doctors_performance_rate                           76.08
# communication_with_doctors_achievement_points                   0 out of 10
# communication_with_doctors_improvement_points                    0 out of 9
# communication_with_doctors_dimension_score                      0 out of 10
# responsiveness_of_hospital_staff_floor                                37.29
# responsiveness_of_hospital_staff_achievement_th...                    65.05
# responsiveness_of_hospital_staff_benchmark                            80.01
# responsiveness_of_hospital_staff_baseline_rate                        56.84
# responsiveness_of_hospital_staff_performance_rate                     55.32
# responsiveness_of_hospital_staff_achievement_po...              0 out of 10
# responsiveness_of_hospital_staff_improvement_po...               0 out of 9
# ...                                                                     ...
# communication_about_medicines_performance_rate                        57.32
# communication_about_medicines_achievement_points                0 out of 10
# communication_about_medicines_improvement_points                 0 out of 9
# communication_about_medicines_dimension_score                   0 out of 10
# cleanliness_and_quietness_of_hospital_environme...                    44.32
# cleanliness_and_quietness_of_hospital_environme...                    65.30
# cleanliness_and_quietness_of_hospital_environme...                    79.39
# cleanliness_and_quietness_of_hospital_environme...                    63.53
# cleanliness_and_quietness_of_hospital_environme...                    59.64
# cleanliness_and_quietness_of_hospital_environme...              0 out of 10
# cleanliness_and_quietness_of_hospital_environme...               0 out of 9
# cleanliness_and_quietness_of_hospital_environme...              0 out of 10
# discharge_information_floor                                           64.09
# discharge_information_achievement_threshold                           85.91
# discharge_information_benchmark                                       91.23
# discharge_information_baseline_rate                                   80.80
# discharge_information_performance_rate                                80.02
# discharge_information_achievement_points                        0 out of 10
# discharge_information_improvement_points                         0 out of 9
# discharge_information_dimension_score                           0 out of 10
# overall_rating_of_hospital_floor                                      35.99
# overall_rating_of_hospital_achievement_threshold                      70.02
# overall_rating_of_hospital_benchmark                                  84.60
# overall_rating_of_hospital_baseline_rate                              61.52
# overall_rating_of_hospital_performance_rate                           61.36
# overall_rating_of_hospital_achievement_points                   0 out of 10
# overall_rating_of_hospital_improvement_points                    0 out of 9
# overall_rating_of_hospital_dimension_score                      0 out of 10
# hcahps_base_score                                                         0
# hcahps_consistency_score                                                 12
#
#                                                                      1  \
# provider_number                                                 150023
# hospital_name                                       UNION HOSPITAL INC
# address                                              1606 N SEVENTH ST
# city                                                       Terre Haute
# state                                                               IN
# zip_code                                                         47804
# county_name                                                       VIGO
# communication_with_nurses_floor                                  58.14
# communication_with_nurses_achievement_threshold                  78.19
# communication_with_nurses_benchmark                              86.61
# communication_with_nurses_baseline_rate                          78.84
# communication_with_nurses_performance_rate                       80.51
# communication_with_nurses_achievement_points               3 out of 10
# communication_with_nurses_improvement_points                2 out of 9
# communication_with_nurses_dimension_score                  3 out of 10
# communication_with_doctors_floor                                 63.58
# communication_with_doctors_achievement_threshold                 80.51
# communication_with_doctors_benchmark                             88.80
# communication_with_doctors_baseline_rate                         76.92
# communication_with_doctors_performance_rate                      75.96
# communication_with_doctors_achievement_points              0 out of 10
# communication_with_doctors_improvement_points               0 out of 9
# communication_with_doctors_dimension_score                 0 out of 10
# responsiveness_of_hospital_staff_floor                           37.29
# responsiveness_of_hospital_staff_achievement_th...               65.05
# responsiveness_of_hospital_staff_benchmark                       80.01
# responsiveness_of_hospital_staff_baseline_rate                   67.09
# responsiveness_of_hospital_staff_performance_rate                66.11
# responsiveness_of_hospital_staff_achievement_po...         1 out of 10
# responsiveness_of_hospital_staff_improvement_po...          0 out of 9
# ...                                                                ...
# communication_about_medicines_performance_rate                   64.13
# communication_about_medicines_achievement_points           2 out of 10
# communication_about_medicines_improvement_points            3 out of 9
# communication_about_medicines_dimension_score              3 out of 10
# cleanliness_and_quietness_of_hospital_environme...               44.32
# cleanliness_and_quietness_of_hospital_environme...               65.30
# cleanliness_and_quietness_of_hospital_environme...               79.39
# cleanliness_and_quietness_of_hospital_environme...               70.81
# cleanliness_and_quietness_of_hospital_environme...               69.08
# cleanliness_and_quietness_of_hospital_environme...         3 out of 10
# cleanliness_and_quietness_of_hospital_environme...          0 out of 9
# cleanliness_and_quietness_of_hospital_environme...         3 out of 10
# discharge_information_floor                                      64.09
# discharge_information_achievement_threshold                      85.91
# discharge_information_benchmark                                  91.23
# discharge_information_baseline_rate                              89.66
# discharge_information_performance_rate                           90.91
# discharge_information_achievement_points                   9 out of 10
# discharge_information_improvement_points                    7 out of 9
# discharge_information_dimension_score                      9 out of 10
# overall_rating_of_hospital_floor                                 35.99
# overall_rating_of_hospital_achievement_threshold                 70.02
# overall_rating_of_hospital_benchmark                             84.60
# overall_rating_of_hospital_baseline_rate                         74.99
# overall_rating_of_hospital_performance_rate                      75.16
# overall_rating_of_hospital_achievement_points              4 out of 10
# overall_rating_of_hospital_improvement_points               0 out of 9
# overall_rating_of_hospital_dimension_score                 4 out of 10
# hcahps_base_score                                                   24
# hcahps_consistency_score                                            14
#
#                                                                               2  \
# provider_number                                                          050742
# hospital_name                                            OLYMPIA MEDICAL CENTER
# address                                             5900 WEST OLYMPIC BOULEVARD
# city                                                                Los Angeles
# state                                                                        CA
# zip_code                                                                  90036
# county_name                                                         LOS ANGELES
# communication_with_nurses_floor                                           58.14
# communication_with_nurses_achievement_threshold                           78.19
# communication_with_nurses_benchmark                                       86.61
# communication_with_nurses_baseline_rate                                   73.01
# communication_with_nurses_performance_rate                                64.65
# communication_with_nurses_achievement_points                        0 out of 10
# communication_with_nurses_improvement_points                         0 out of 9
# communication_with_nurses_dimension_score                           0 out of 10
# communication_with_doctors_floor                                          63.58
# communication_with_doctors_achievement_threshold                          80.51
# communication_with_doctors_benchmark                                      88.80
# communication_with_doctors_baseline_rate                                  78.00
# communication_with_doctors_performance_rate                               72.22
# communication_with_doctors_achievement_points                       0 out of 10
# communication_with_doctors_improvement_points                        0 out of 9
# communication_with_doctors_dimension_score                          0 out of 10
# responsiveness_of_hospital_staff_floor                                    37.29
# responsiveness_of_hospital_staff_achievement_th...                        65.05
# responsiveness_of_hospital_staff_benchmark                                80.01
# responsiveness_of_hospital_staff_baseline_rate                            59.55
# responsiveness_of_hospital_staff_performance_rate                         52.04
# responsiveness_of_hospital_staff_achievement_po...                  0 out of 10
# responsiveness_of_hospital_staff_improvement_po...                   0 out of 9
# ...                                                                         ...
# communication_about_medicines_performance_rate                            52.85
# communication_about_medicines_achievement_points                    0 out of 10
# communication_about_medicines_improvement_points                     0 out of 9
# communication_about_medicines_dimension_score                       0 out of 10
# cleanliness_and_quietness_of_hospital_environme...                        44.32
# cleanliness_and_quietness_of_hospital_environme...                        65.30
# cleanliness_and_quietness_of_hospital_environme...                        79.39
# cleanliness_and_quietness_of_hospital_environme...                        68.00
# cleanliness_and_quietness_of_hospital_environme...                        58.62
# cleanliness_and_quietness_of_hospital_environme...                  0 out of 10
# cleanliness_and_quietness_of_hospital_environme...                   0 out of 9
# cleanliness_and_quietness_of_hospital_environme...                  0 out of 10
# discharge_information_floor                                               64.09
# discharge_information_achievement_threshold                               85.91
# discharge_information_benchmark                                           91.23
# discharge_information_baseline_rate                                       81.54
# discharge_information_performance_rate                                    78.67
# discharge_information_achievement_points                            0 out of 10
# discharge_information_improvement_points                             0 out of 9
# discharge_information_dimension_score                               0 out of 10
# overall_rating_of_hospital_floor                                          35.99
# overall_rating_of_hospital_achievement_threshold                          70.02
# overall_rating_of_hospital_benchmark                                      84.60
# overall_rating_of_hospital_baseline_rate                                  64.76
# overall_rating_of_hospital_performance_rate                               58.25
# overall_rating_of_hospital_achievement_points                       0 out of 10
# overall_rating_of_hospital_improvement_points                        0 out of 9
# overall_rating_of_hospital_dimension_score                          0 out of 10
# hcahps_base_score                                                             0
# hcahps_consistency_score                                                      6
#
#                                                                                 3  \
# provider_number                                                            150182
# hospital_name                                            FRANCISCAN HEALTH CARMEL
# address                                             12188 B NORTH MERIDIAN STREET
# city                                                                       Carmel
# state                                                                          IN
# zip_code                                                                    46240
# county_name                                                              HAMILTON
# communication_with_nurses_floor                                             58.14
# communication_with_nurses_achievement_threshold                             78.19
# communication_with_nurses_benchmark                                         86.61
# communication_with_nurses_baseline_rate                             Not Available
# communication_with_nurses_performance_rate                                  94.15
# communication_with_nurses_achievement_points                         10 out of 10
# communication_with_nurses_improvement_points                        Not Available
# communication_with_nurses_dimension_score                            10 out of 10
# communication_with_doctors_floor                                            63.58
# communication_with_doctors_achievement_threshold                            80.51
# communication_with_doctors_benchmark                                        88.80
# communication_with_doctors_baseline_rate                            Not Available
# communication_with_doctors_performance_rate                                 92.22
# communication_with_doctors_achievement_points                        10 out of 10
# communication_with_doctors_improvement_points                       Not Available
# communication_with_doctors_dimension_score                           10 out of 10
# responsiveness_of_hospital_staff_floor                                      37.29
# responsiveness_of_hospital_staff_achievement_th...                          65.05
# responsiveness_of_hospital_staff_benchmark                                  80.01
# responsiveness_of_hospital_staff_baseline_rate                      Not Available
# responsiveness_of_hospital_staff_performance_rate                           94.14
# responsiveness_of_hospital_staff_achievement_po...                   10 out of 10
# responsiveness_of_hospital_staff_improvement_po...                  Not Available
# ...                                                                           ...
# communication_about_medicines_performance_rate                              72.09
# communication_about_medicines_achievement_points                      8 out of 10
# communication_about_medicines_improvement_points                    Not Available
# communication_about_medicines_dimension_score                         8 out of 10
# cleanliness_and_quietness_of_hospital_environme...                          44.32
# cleanliness_and_quietness_of_hospital_environme...                          65.30
# cleanliness_and_quietness_of_hospital_environme...                          79.39
# cleanliness_and_quietness_of_hospital_environme...                  Not Available
# cleanliness_and_quietness_of_hospital_environme...                          77.53
# cleanliness_and_quietness_of_hospital_environme...                    8 out of 10
# cleanliness_and_quietness_of_hospital_environme...                  Not Available
# cleanliness_and_quietness_of_hospital_environme...                    8 out of 10
# discharge_information_floor                                                 64.09
# discharge_information_achievement_threshold                                 85.91
# discharge_information_benchmark                                             91.23
# discharge_information_baseline_rate                                 Not Available
# discharge_information_performance_rate                                      92.96
# discharge_information_achievement_points                             10 out of 10
# discharge_information_improvement_points                            Not Available
# discharge_information_dimension_score                                10 out of 10
# overall_rating_of_hospital_floor                                            35.99
# overall_rating_of_hospital_achievement_threshold                            70.02
# overall_rating_of_hospital_benchmark                                        84.60
# overall_rating_of_hospital_baseline_rate                            Not Available
# overall_rating_of_hospital_performance_rate                                 85.75
# overall_rating_of_hospital_achievement_points                        10 out of 10
# overall_rating_of_hospital_improvement_points                       Not Available
# overall_rating_of_hospital_dimension_score                           10 out of 10
# hcahps_base_score                                                              76
# hcahps_consistency_score                                                       20
#
#                                                                               4
# provider_number                                                          180064
# hospital_name                                       SAINT JOSEPH MOUNT STERLING
# address                                                        225 FALCON DRIVE
# city                                                             Mount Sterling
# state                                                                        KY
# zip_code                                                                  40353
# county_name                                                          MONTGOMERY
# communication_with_nurses_floor                                           58.14
# communication_with_nurses_achievement_threshold                           78.19
# communication_with_nurses_benchmark                                       86.61
# communication_with_nurses_baseline_rate                                   81.13
# communication_with_nurses_performance_rate                                81.25
# communication_with_nurses_achievement_points                        4 out of 10
# communication_with_nurses_improvement_points                         0 out of 9
# communication_with_nurses_dimension_score                           4 out of 10
# communication_with_doctors_floor                                          63.58
# communication_with_doctors_achievement_threshold                          80.51
# communication_with_doctors_benchmark                                      88.80
# communication_with_doctors_baseline_rate                                  81.56
# communication_with_doctors_performance_rate                               82.07
# communication_with_doctors_achievement_points                       2 out of 10
# communication_with_doctors_improvement_points                        0 out of 9
# communication_with_doctors_dimension_score                          2 out of 10
# responsiveness_of_hospital_staff_floor                                    37.29
# responsiveness_of_hospital_staff_achievement_th...                        65.05
# responsiveness_of_hospital_staff_benchmark                                80.01
# responsiveness_of_hospital_staff_baseline_rate                            70.28
# responsiveness_of_hospital_staff_performance_rate                         68.01
# responsiveness_of_hospital_staff_achievement_po...                  2 out of 10
# responsiveness_of_hospital_staff_improvement_po...                   0 out of 9
# ...                                                                         ...
# communication_about_medicines_performance_rate                            69.31
# communication_about_medicines_achievement_points                    6 out of 10
# communication_about_medicines_improvement_points                     0 out of 9
# communication_about_medicines_dimension_score                       6 out of 10
# cleanliness_and_quietness_of_hospital_environme...                        44.32
# cleanliness_and_quietness_of_hospital_environme...                        65.30
# cleanliness_and_quietness_of_hospital_environme...                        79.39
# cleanliness_and_quietness_of_hospital_environme...                        72.14
# cleanliness_and_quietness_of_hospital_environme...                        71.56
# cleanliness_and_quietness_of_hospital_environme...                  4 out of 10
# cleanliness_and_quietness_of_hospital_environme...                   0 out of 9
# cleanliness_and_quietness_of_hospital_environme...                  4 out of 10
# discharge_information_floor                                               64.09
# discharge_information_achievement_threshold                               85.91
# discharge_information_benchmark                                           91.23
# discharge_information_baseline_rate                                       90.57
# discharge_information_performance_rate                                    92.26
# discharge_information_achievement_points                           10 out of 10
# discharge_information_improvement_points                             9 out of 9
# discharge_information_dimension_score                              10 out of 10
# overall_rating_of_hospital_floor                                          35.99
# overall_rating_of_hospital_achievement_threshold                          70.02
# overall_rating_of_hospital_benchmark                                      84.60
# overall_rating_of_hospital_baseline_rate                                  75.88
# overall_rating_of_hospital_performance_rate                               70.91
# overall_rating_of_hospital_achievement_points                       1 out of 10
# overall_rating_of_hospital_improvement_points                        0 out of 9
# overall_rating_of_hospital_dimension_score                          1 out of 10
# hcahps_base_score                                                            29
# hcahps_consistency_score                                                     18
#
# [73 rows x 5 columns]

# %% [markdown]
# ### Some Exploratory Data Analysis

# %% [markdown]
# #### Hospital Table

# %% [markdown]
# Let's start by examining the Hospital table and looking at the variable 'hospital_overall_rating'. It appears that each hospital is being ranked between 1-5, with numerous counts of 'Not Available'

# %%
hospitals['hospital_overall_rating'].value_counts()
# Out:
# 3                1755
# Not Available    1252
# 4                 938
# 2                 678
# 1                 107
# 5                  82
# Name: hospital_overall_rating, dtype: int64

# %% [markdown]
# Let's replace 'Not Available' with NaNs and convert to numeric. We can then groupby county, states to get a gauge of overall rating by geography

# %%
hospitals['hospital_overall_rating'] = (pd.to_numeric(hospitals['hospital_overall_rating']
                                                      .replace('Not Available', np.nan)))

# %%
hospitals.groupby(['state']).mean().sort_values(by='hospital_overall_rating')
# Out:
#        hospital_overall_rating
# state
# DC                    1.428571
# VI                    2.000000
# PR                    2.111111
# NY                    2.320261
# NV                    2.400000
# NJ                    2.546875
# FL                    2.662722
# NM                    2.709677
# CT                    2.714286
# WV                    2.756757
# MS                    2.777778
# AR                    2.836364
# CA                    2.841379
# TN                    2.870968
# AK                    2.888889
# GA                    2.935185
# AZ                    2.944444
# KY                    2.975904
# WY                    3.000000
# GU                    3.000000
# PA                    3.006849
# MO                    3.011628
# VA                    3.013158
# WA                    3.015152
# AL                    3.050633
# NC                    3.106383
# LA                    3.126582
# IL                    3.132075
# OK                    3.151899
# OR                    3.153846
# MA                    3.178571
# ND                    3.187500
# MI                    3.191304
# SC                    3.192308
# TX                    3.233716
# VT                    3.250000
# RI                    3.272727
# NE                    3.291667
# HI                    3.307692
# KS                    3.344828
# MT                    3.347826
# OH                    3.378571
# IA                    3.394366
# ME                    3.437500
# UT                    3.448276
# CO                    3.450980
# NH                    3.480000
# IN                    3.481481
# ID                    3.526316
# MN                    3.531646
# WI                    3.611111
# DE                    3.666667
# SD                    3.857143
# AS                         NaN
# MD                         NaN
# MP                         NaN

# %% [markdown]
# It appears that DC, VI, PR, NY are the top 4 worst states for hospital overall ratings and SD, DE, WI, MN are the best

# %% [markdown]
# Quick barplot to visualize the above

# %%
sb.barplot(x='state', y='hospital_overall_rating', data=hospitals)
plt.ylabel('Hospital Overall Rating',fontsize=14);
plt.xlabel('State', fontsize=14);
plt.title('Average Hospital Overall Rating by State', fontsize=14);

# %% [markdown]
# Next let's examine if the different types of ownership has anything to do with overall rating

# %%
hospitals.hospital_ownership.value_counts()
# Out:
# Voluntary non-profit - Private                 2057
# Proprietary                                     804
# Government - Hospital District or Authority     559
# Voluntary non-profit - Other                    461
# Government - Local                              404
# Voluntary non-profit - Church                   338
# Physician                                        67
# Government - State                               66
# Government - Federal                             47
# Tribal                                            9
# Name: hospital_ownership, dtype: int64

# %%
sb.barplot(x='hospital_ownership', y='hospital_overall_rating', data=hospitals)
plt.xticks(rotation=45);
plt.ylabel('Hospital Overall Rating',fontsize=14);
plt.xlabel('Hospital Ownership Type', fontsize=14);
plt.title('Average Hospital Overall Rating vs. Ownership Type', fontsize=14);

# %% [markdown]
# It appears that Hospitals that are directly owned by the Physicians have the highest overall rating, while hospitals that are owned by Tribal have the lowest

# %% [markdown]
# After briefly examining the Hospitals table, it appears that it is most useful to keep the following columns for the rest of our formal analysis:
#
# - 'provider_id',
# - 'hospital_name',
# - 'city',
# - 'state',
# - 'zip_code',
# - 'county_name',
# - 'hospital_type',
# - 'hospital_ownership',
# - 'meets_criteria',
# - 'hospital_overall_rating',
# - 'mortality_national_compare',
# - 'safety_of_care_national_comparison',
# - 'readmission_national_comparison',
# - 'patient_experience_national_comparison',
# - 'effectiveness_of_care_national_comparison',
# - 'timeliness_of_care_national_comparison'
#
# We will keep the values of all ratings, score columns as strings for now given that we will do our aggregations in Pandas

# %% [markdown]
# #### We will next examine the Survey_Responses Table

# %% [markdown]
# The Survey Responses table gives more granular measurements about each hospital based on survey results. There are numerous columns that give results in the form "X out of 10" and we would like to glean information from this so we need to convert to numeric values

# %%
## Function to strip ' out of ' string from Series values 

def get_numeric_out_of(series):
    series = series.str.split(' out of ').str.get(0)
    return series

# %%
scored_columns = ['communication_with_nurses_dimension_score',
                  'communication_with_doctors_dimension_score',
                  'responsiveness_of_hospital_staff_dimension_score',
                  'communication_about_medicines_dimension_score',
                  'cleanliness_and_quietness_of_hospital_environment_dimension_score', 
                  'discharge_information_dimension_score',
                  'overall_rating_of_hospital_dimension_score']

# %%
survey_responses[scored_columns] = survey_responses[scored_columns].apply(get_numeric_out_of)

# %% [markdown]
# The below code writes the above transformed DataFrame back into Hive. We will put this in a stand alone .py file that is executable in the folder 'transforming'

# %%
# spark_df = hc.createDataFrame(survey_responses)
# spark_df.write.saveAsTable('survey_responses_reduced')

# %% [markdown]
# ### Effective Care

# %% [markdown]
# We notice that the effective_care table has two types of metrics for measure_ids. Using a measure_id of 'EDV' or Emergency Department Volumen, we notice that the scores are in volumetric measurements whereas the rest of the measure_ids are on a numeric scale

# %%
effective_care[effective_care['measure_id']=='EDV']['score'].value_counts()
# Out:
# Not Available                                 1362
# Low (0 - 19,999 patients annually)            1211
# Medium (20,000 - 39,999 patients annually)     961
# Very High (60,000+ patients annually)          680
# High (40,000 - 59,999 patients annually)       598
# Name: score, dtype: int64

# %%
effective_care[effective_care['measure_id']!='EDV']['score'].value_counts()
# Out:
# Not Available    51501
# 100               4009
# 0                 3030
# 1                 1551
# 98                1485
# 99                1471
# 97                1262
# 2                 1148
# 96                1093
# 95                1029
# 94                 926
# 93                 842
# 3                  749
# 92                 736
# 91                 651
# 4                  637
# 90                 577
# 6                  550
# 5                  523
# 88                 505
# 8                  497
# 89                 477
# 7                  453
# 86                 435
# 85                 383
# 87                 382
# 82                 370
# 83                 350
# 10                 344
# 80                 333
#                  ...
# 572                  1
# 527                  1
# 544                  1
# 526                  1
# 384                  1
# 427                  1
# 538                  1
# 531                  1
# 533                  1
# 534                  1
# 535                  1
# 845                  1
# 417                  1
# 414                  1
# 548                  1
# 552                  1
# 571                  1
# 551                  1
# 557                  1
# 477                  1
# 476                  1
# 471                  1
# 567                  1
# 561                  1
# 560                  1
# 466                  1
# 464                  1
# 469                  1
# 576                  1
# 573                  1
# Name: score, Length: 587, dtype: int64

# %% [markdown]
# We will split the effective_care table by seperating out the scores that are pertaining to Emergency Department Volume from the rest of the scores

# %%
effective_care_regular = effective_care[effective_care['measure_id']!='EDV']
effective_care_vol = effective_care[effective_care['measure_id'] =='EDV']

# %%
effective_care_regular.loc[:, 'score'] = pd.to_numeric(effective_care_regular.loc[:, 'score']
                                                                             .replace('Not Available', np.nan))
# Out:
# /home/w205/data/anaconda2/lib/python2.7/site-packages/pandas/core/indexing.py:601: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item_labels[indexer[info_axis]]] = value

# %%
effective_care_regular.head()
# Out:
#   provider_id                     hospital_name                 address  \
# 0      010001  SOUTHEAST ALABAMA MEDICAL CENTER  1108 ROSS CLARK CIRCLE
# 1      010001  SOUTHEAST ALABAMA MEDICAL CENTER  1108 ROSS CLARK CIRCLE
# 3      010001  SOUTHEAST ALABAMA MEDICAL CENTER  1108 ROSS CLARK CIRCLE
# 4      010001  SOUTHEAST ALABAMA MEDICAL CENTER  1108 ROSS CLARK CIRCLE
# 5      010001  SOUTHEAST ALABAMA MEDICAL CENTER  1108 ROSS CLARK CIRCLE
#
#      city state zip_code county_name phone_number                   condition  \
# 0  DOTHAN    AL    36301     HOUSTON   3347938701        Emergency Department
# 1  DOTHAN    AL    36301     HOUSTON   3347938701        Emergency Department
# 3  DOTHAN    AL    36301     HOUSTON   3347938701             Preventive Care
# 4  DOTHAN    AL    36301     HOUSTON   3347938701             Preventive Care
# 5  DOTHAN    AL    36301     HOUSTON   3347938701  Heart Attack or Chest Pain
#
#                measure_id                                    measure_name  \
# 0                   ED_1b                                             ED1
# 1                   ED_2b                                             ED2
# 3                   IMM_2                      Immunization for influenza
# 4  IMM_3_OP_27_FAC_ADHPCT  Healthcare workers given influenza vaccination
# 5                    OP_1                     Median Time to Fibrinolysis
#
#    score         sample                                           footnote  \
# 0  286.0            569  2 - Data submitted were based on a sample of c...
# 1   99.0            569  2 - Data submitted were based on a sample of c...
# 3   95.0            554  2 - Data submitted were based on a sample of c...
# 4   86.0           4457
# 5    NaN  Not Available  5 - Results are not available for this reporti...
#
#   measure_start_date measure_end_date
# 0         01/01/2016       12/31/2016
# 1         01/01/2016       12/31/2016
# 3         10/01/2015       03/31/2016
# 4         10/01/2016       03/31/2017
# 5         01/01/2016       12/31/2016

# %%
sb.boxplot(x = effective_care_regular['measure_id'], y = effective_care_regular['score'])
plt.xticks(rotation=45);

# %% [markdown]
# Out of the various measures at each hospital, we see that ED_1b has the highest variability. This measure_id stands for the "Average (median) time patients spent in the emergency department, before they were admitted to the hospital as an inpatient (alternate Measure ID: ED-1)"
#
# Let's examine some hospitals with high scores on ED_1b

# %%
effective_care_regular[effective_care_regular['measure_id']=='ED_1b'].sort_values(by='score', ascending=False)
# Out:
#        provider_id                                     hospital_name  \
# 81158       400079                  HOSP COMUNITARIO BUEN SAMARITANO
# 81202       400098                            HOSPITAL SAN FRANCISCO
# 81488       400117                            HOSPITAL DR SUSONI INC
# 80982       400019                           HOSPITAL PAVIA SANTURCE
# 6512        050060                 COMMUNITY REGIONAL MEDICAL CENTER
# 10054       050492                   CLOVIS COMMUNITY MEDICAL CENTER
# 80894       400014                              BELLA VISTA HOSPITAL
# 81290       400105              HOSPITAL UNIVERSITARIO DR RUIZ ARNAU
# 8998        050315                               KERN MEDICAL CENTER
# 81708       400128                      HOSPITAL PAVIA HATO REY, INC
# 63294       330128                          ELMHURST HOSPITAL CENTER
# 80872       400013                        HOSPITAL MENONITA DE CAYEY
# 8800        050295                                    MERCY HOSPITAL
# 81642       400125                            HIMA-SAN PABLO FAJARDO
# 81180       400087                 HOSPITAL DR CAYETANO COLL Y TOSTE
# 64042       330202                      KINGS COUNTY HOSPITAL CENTER
# 81532       400120                             HIMA SAN PABLO-CAGUAS
# 9064        050327              LOMA LINDA UNIVERSITY MEDICAL CENTER
# 81092       400044                  SAN LUKE'S MEMORIAL HOSPITAL INC
# 80938       400016                            AUXILIO MUTUO HOSPITAL
# 63404       330141       BROOKHAVEN MEMORIAL HOSPITAL MEDICAL CENTER
# 10274       050517               VICTOR VALLEY GLOBAL MEDICAL CENTER
# 81004       400021                         HOSPITAL DE LA CONCEPCION
# 63756       330182                       ST FRANCIS HOSPITAL, ROSLYN
# 21296       110079                           GRADY MEMORIAL HOSPITAL
# 81312       400106                             METROPOLITAN HOSPITAL
# 81400       400112                 HOSPITAL UPR, DR  FEDERICO TRILLA
# 16104       090006                               PROVIDENCE HOSPITAL
# 81268       400104                      HOSPITAL MENONITA CAGUAS INC
# 63008       330101                    NEW YORK-PRESBYTERIAN HOSPITAL
# ...            ...                                               ...
# 104236      531314                     NIOBRARA HEALTH & LIFE CENTER
# 104258      531315                SOUTH LINCOLN MEDICAL CENTER - CAH
# 104280      531316                MEMORIAL HOSPITAL OF CARBON COUNTY
# 104324      670005       MEMORIAL HERMANN SURGICAL HOSPITAL KINGWOOD
# 104390      670010                                  MAYHILL HOSPITAL
# 104588      670045            COOK CHILDRENS NORTHEAST HOSPITAL, LLC
# 104610      670046                   USMD HOSPITAL  AT FORT WORTH LP
# 104654      670049                 NORTH CENTRAL SURGICAL CENTER LLP
# 104698      670054       FOUNDATION SURGICAL HOSPITAL OF SAN ANTONIO
# 104764      670058                                   EMERUS HOSPITAL
# 104830      670061                     SOUTH TEXAS SURGICAL HOSPITAL
# 104940      670071  TEXAS HEALTH HEART & VASCULAR HOSPITAL ARLINGTON
# 104962      670072                               HOPEBRIDGE HOSPITAL
# 104984      670073                    METHODIST HOSPITAL FOR SURGERY
# 105270      670093           ASPIRE BEHAVIORAL HEALTH OF CONROE, LLC
# 105324      640001                       LBJ TROPICAL MEDICAL CENTER
# 105368      650003                        GUAM REGIONAL MEDICAL CITY
# 105390      660001                        COMMONWEALTH HEALTH CENTER
# 105490      670099                    EMIL J FREIREICH CANCER CENTER
# 105512      670102                             AD HOSPITAL EAST, LLC
# 105622      670109                            ALTUS BAYTOWN HOSPITAL
# 105666      670111    CONTINUECARE HOSPITAL AT MEDICAL CENTER ODESSA
# 105688      670112                      CUMBERLAND SURGICAL HOSPITAL
# 105710      670114                             WEIMAR MEDICAL CENTER
# 105732      670115                      CLEVELAND EMERGENCY HOSPTIAL
# 105754      670116                                WISE HEALTH SYSTEM
# 105776      670117                  TEXAS GENERAL HOSPITAL- VZRMC LP
# 105798      670118                              FIRST TEXAS HOSPITAL
# 105820      670119          PROVIDENCE HOSPITAL OF NORTH HOUSTON LLC
# 105842      670120  THE HOSPITALS OF PROVIDENCE TRANSMOUNTAIN CAMPUS
#
#                                                   address              city  \
# 81158             CARR.2 KM.1.4 AVE. SEVERIANO CUEVAS #18         AGUADILLA
# 81202                                    371 DE DIEGO AVE          SAN JUAN
# 81488                                          55 PALM ST           ARECIBO
# 80982              CALLE PROFESOR AUGUSTO RODRIGUEZ #1462  FERNANDEZ JUNCOS
# 6512                                   2823 FRESNO STREET            FRESNO
# 10054                                    2755 HERNDON AVE            CLOVIS
# 80894                     CARR 349 KM 2 7 CERRO LAS MESAS          MAYAGUEZ
# 81290                       LAUREL AVE SANTA JUANITA #100           BAYAMON
# 8998                             1700 MOUNT VERNON AVENUE       BAKERSFIELD
# 81708                               AVE PONCE DE LEON 435          HATO REY
# 63294                                      79-01 BROADWAY          ELMHURST
# 80872         BO. RINCON SECTOR LAS LOMAS  KM.3.1 CARR 14             CAYEY
# 8800                                  2215 TRUXTUN AVENUE       BAKERSFIELD
# 81642                              GENERAL VALERO AVE#404           FAJARDO
# 81180                 CARRETERA 129 KM.1 AVENIDA SAN LUIS           ARECIBO
# 64042                                 451 CLARKSON AVENUE          BROOKLYN
# 81532                                AVE LUIS MUNOZ MARIN            CAGUAS
# 9064                                    11234 ANDERSON ST        LOMA LINDA
# 81092                                TITO CASTRO AVE #917             PONCE
# 80938               PONCE DE LEON AVENUE STOP 36 1/2 #735          HATO REY
# 63404                                   101 HOSPITAL ROAD         PATCHOGUE
# 10274                                       15248 11TH ST       VICTORVILLE
# 81004                    ROAD NUMBER 2 KM 173.4 CAIN ALTO        SAN GERMAN
# 63756                       100 PORT WASHINGTON BOULEVARD            ROSLYN
# 21296                          80 JESSE HILL, JR DRIVE SE           ATLANTA
# 81312                     CARRETERA 21 1785 URB LAS LOMAS          SAN JUAN
# 81400   CARR 3 KM 8  3 AVE 65TH INFANTERIA       BOX 6021          CAROLINA
# 16104                                   1150 VARNUM ST NE        WASHINGTON
# 81268                CARR 172  EXIT 21 URB TURABO GARDENS            CAGUAS
# 63008                                525 EAST 68TH STREET          NEW YORK
# ...                                                   ...               ...
# 104236                         921 SOUTH BALLANCEE AVENUE              LUSK
# 104258                                    711 ONYX STREET          KEMMERER
# 104280                               2221 WEST ELM STREET           RAWLINS
# 104324                         300 KINGWOOD MEDICAL DRIVE          KINGWOOD
# 104390                            2809 SOUTH MAYHILL ROAD            DENTON
# 104588                              6316 PRECINCT LINE RD             HURST
# 104610                                 5900 ALTAMESA BLVD        FORT WORTH
# 104654            9301 NORTH CENTRAL EXPRESSWAY SUITE 100            DALLAS
# 104698                                  9522 HUEBNER ROAD       SAN ANTONIO
# 104764                            16000 SOUTHWEST FREEWAY        SUGAR LAND
# 104830                                 6130 PARKWAY DRIVE    CORPUS CHRISTI
# 104940                                  811 WRIGHT STREET         ARLINGTON
# 104962                                  5556 GASMER DRIVE           HOUSTON
# 104984                               17101 DALLAS PARKWAY           ADDISON
# 105270                2006 SOUTH LOOP 336 WEST, SUITE 500            CONROE
# 105324                                    FAGAALU VILLAGE         PAGO PAGO
# 105368                                        133 ROUTE 3            DEDEDO
# 105390                       PO BOX 409CK, NAVY HILL ROAD           GARAPAN
# 105490                                     9201 PINECROFT        SHENANDOAH
# 105512                      12950 EAST FREEWAY, SUITE 100           HOUSTON
# 105622                                    1626 W BAKER RD           BAYTOWN
# 105666                   500 WEST  4TH STREET , 4TH FLOOR            ODESSA
# 105688                          5330 NORTH LOOP 1604 WEST       SAN ANTONIO
# 105710                                      400 YOUENS DR            WEIMAR
# 105732                                  1017 S TRAVIS AVE         CLEVELAND
# 105754                         3200 NORTH TARRANT PARKWAY        FORT WORTH
# 105776                                   707 N WALDRIP ST      GRAND SALINE
# 105798                                    9922 LOUETTA RD           HOUSTON
# 105820                                16750 RED OAK DRIVE           HOUSTON
# 105842                              2000 TRANSMOUNTAIN RD           EL PASO
#
#        state zip_code           county_name phone_number  \
# 81158     PR    00603             AGUADILLA   7876580000
# 81202     PR    00923              SAN JUAN   7877675100
# 81488     PR    00614               ARECIBO   7876501031
# 80982     PR    00910              SAN JUAN   7877276060
# 6512      CA    93721                FRESNO   5594596000
# 10054     CA    93611                FRESNO   5593244000
# 80894     PR    00681              MAYAGUEZ   7876526045
# 81290     PR    00956               BAYAMON   7877875151
# 8998      CA    93306                  KERN   6613262000
# 81708     PR    00919              SAN JUAN   7877540909
# 63294     NY    11373                QUEENS   7183341141
# 80872     PR    00737                 CAYEY   7875351001
# 8800      CA    93301                  KERN   6616325000
# 81642     PR    00738               FAJARDO   7876550505
# 81180     PR    00613               ARECIBO   7876507272
# 64042     NY    11203                 KINGS   7182453901
# 81532     PR    00725                CAGUAS   7876533434
# 9064      CA    92354        SAN BERNARDINO   9095584000
# 81092     PR    00733                 PONCE   7878442080
# 80938     PR    00918              SAN JUAN   7877582000
# 63404     NY    11772               SUFFOLK   6316547100
# 10274     CA    92392        SAN BERNARDINO   7602458691
# 81004     PR    00683            SAN GERMAN   7878921860
# 63756     NY    11576                NASSAU   5165626000
# 21296     GA    30303                FULTON   4046164252
# 81312     PR    00915              SAN JUAN   7877829999
# 81400     PR    00984              CAROLINA   7877571800
# 16104     DC    20017  DISTRICT OF COLUMBIA   2022697000
# 81268     PR    00725                CAGUAS   7877443141
# 63008     NY    10065              NEW YORK   2127465454
# ...      ...      ...                   ...          ...
# 104236    WY    82225              NIOBRARA   3073344000
# 104258    WY    83101               LINCOLN   3078774401
# 104280    WY    82301                CARBON   3073242221
# 104324    TX    77339                HARRIS   2813124000
# 104390    TX    76208                DENTON   9402393000
# 104588    TX    76054               TARRANT   8176052500
# 104610    TX    76132               TARRANT   8174339100
# 104654    TX    75231                DALLAS   2142652810
# 104698    TX    78240                 BEXAR   2104785400
# 104764    TX    77479             FORT BEND   2815160911
# 104830    TX    78414                NUECES   3619932000
# 104940    TX    76012               TARRANT   8179603500
# 104962    TX    77035                HARRIS   7134222650
# 104984    TX    75001                DALLAS   4692483900
# 105270    TX    77304            MONTGOMERY   9366473500
# 105324    AS    96799                         6846334590
# 105368    GU    96929                         6716455500
# 105390    MP    96950                         6702348950
# 105490    TX    77380            MONTGOMERY   8553532201
# 105512    TX    77015                HARRIS   7133303897
# 105622    TX    77521                HARRIS   2818377600
# 105666    TX    79761                 ECTOR   2176163297
# 105688    TX    78249                 BEXAR   7176202424
# 105710    TX    78962              COLORADO   9797258274
# 105732    TX    77327               LIBERTY   2816595400
# 105754    TX    76177               TARRANT   8175027300
# 105776    TX    75140             VAN ZANDT   9039625200
# 105798    TX    77070                HARRIS   8442641435
# 105820    TX    77090                HARRIS   2814537916
# 105842    TX    79911               EL PASO   9158778136
#
#                    condition measure_id measure_name   score         sample  \
# 81158   Emergency Department      ED_1b          ED1  1239.0           1052
# 81202   Emergency Department      ED_1b          ED1  1221.0            552
# 81488   Emergency Department      ED_1b          ED1  1129.0            237
# 80982   Emergency Department      ED_1b          ED1  1098.0           1592
# 6512    Emergency Department      ED_1b          ED1  1059.0            683
# 10054   Emergency Department      ED_1b          ED1   934.0            415
# 80894   Emergency Department      ED_1b          ED1   930.0            775
# 81290   Emergency Department      ED_1b          ED1   927.0            628
# 8998    Emergency Department      ED_1b          ED1   895.0            475
# 81708   Emergency Department      ED_1b          ED1   894.0             26
# 63294   Emergency Department      ED_1b          ED1   891.0            693
# 80872   Emergency Department      ED_1b          ED1   885.0            434
# 8800    Emergency Department      ED_1b          ED1   845.0            677
# 81642   Emergency Department      ED_1b          ED1   841.0            582
# 81180   Emergency Department      ED_1b          ED1   822.0            488
# 64042   Emergency Department      ED_1b          ED1   790.0            838
# 81532   Emergency Department      ED_1b          ED1   749.0           1151
# 9064    Emergency Department      ED_1b          ED1   746.0            702
# 81092   Emergency Department      ED_1b          ED1   742.0            846
# 80938   Emergency Department      ED_1b          ED1   736.0            998
# 63404   Emergency Department      ED_1b          ED1   734.0           1226
# 10274   Emergency Department      ED_1b          ED1   733.0            963
# 81004   Emergency Department      ED_1b          ED1   729.0            687
# 63756   Emergency Department      ED_1b          ED1   729.0            815
# 21296   Emergency Department      ED_1b          ED1   724.0            748
# 81312   Emergency Department      ED_1b          ED1   720.0            947
# 81400   Emergency Department      ED_1b          ED1   712.0            931
# 16104   Emergency Department      ED_1b          ED1   703.0            647
# 81268   Emergency Department      ED_1b          ED1   702.0            592
# 63008   Emergency Department      ED_1b          ED1   686.0           1708
# ...                      ...        ...          ...     ...            ...
# 104236  Emergency Department      ED_1b          ED1     NaN  Not Available
# 104258  Emergency Department      ED_1b          ED1     NaN  Not Available
# 104280  Emergency Department      ED_1b          ED1     NaN  Not Available
# 104324  Emergency Department      ED_1b          ED1     NaN  Not Available
# 104390  Emergency Department      ED_1b          ED1     NaN  Not Available
# 104588  Emergency Department      ED_1b          ED1     NaN  Not Available
# 104610  Emergency Department      ED_1b          ED1     NaN  Not Available
# 104654  Emergency Department      ED_1b          ED1     NaN  Not Available
# 104698  Emergency Department      ED_1b          ED1     NaN  Not Available
# 104764  Emergency Department      ED_1b          ED1     NaN  Not Available
# 104830  Emergency Department      ED_1b          ED1     NaN  Not Available
# 104940  Emergency Department      ED_1b          ED1     NaN  Not Available
# 104962  Emergency Department      ED_1b          ED1     NaN  Not Available
# 104984  Emergency Department      ED_1b          ED1     NaN  Not Available
# 105270  Emergency Department      ED_1b          ED1     NaN  Not Available
# 105324  Emergency Department      ED_1b          ED1     NaN  Not Available
# 105368  Emergency Department      ED_1b          ED1     NaN  Not Available
# 105390  Emergency Department      ED_1b          ED1     NaN  Not Available
# 105490  Emergency Department      ED_1b          ED1     NaN  Not Available
# 105512  Emergency Department      ED_1b          ED1     NaN  Not Available
# 105622  Emergency Department      ED_1b          ED1     NaN  Not Available
# 105666  Emergency Department      ED_1b          ED1     NaN  Not Available
# 105688  Emergency Department      ED_1b          ED1     NaN  Not Available
# 105710  Emergency Department      ED_1b          ED1     NaN  Not Available
# 105732  Emergency Department      ED_1b          ED1     NaN  Not Available
# 105754  Emergency Department      ED_1b          ED1     NaN  Not Available
# 105776  Emergency Department      ED_1b          ED1     NaN  Not Available
# 105798  Emergency Department      ED_1b          ED1     NaN  Not Available
# 105820  Emergency Department      ED_1b          ED1     NaN  Not Available
# 105842  Emergency Department      ED_1b          ED1     NaN  Not Available
#
#                                                  footnote measure_start_date  \
# 81158   2 - Data submitted were based on a sample of c...         01/01/2016
# 81202   2 - Data submitted were based on a sample of c...         01/01/2016
# 81488   2 - Data submitted were based on a sample of c...         01/01/2016
# 80982                                                             01/01/2016
# 6512    2 - Data submitted were based on a sample of c...         01/01/2016
# 10054   2 - Data submitted were based on a sample of c...         01/01/2016
# 80894   2 - Data submitted were based on a sample of c...         01/01/2016
# 81290   2 - Data submitted were based on a sample of c...         01/01/2016
# 8998    2 - Data submitted were based on a sample of c...         01/01/2016
# 81708   2 - Data submitted were based on a sample of c...         01/01/2016
# 63294   2 - Data submitted were based on a sample of c...         01/01/2016
# 80872   2 - Data submitted were based on a sample of c...         01/01/2016
# 8800    2 - Data submitted were based on a sample of c...         01/01/2016
# 81642   2 - Data submitted were based on a sample of c...         01/01/2016
# 81180                                                             01/01/2016
# 64042   2 - Data submitted were based on a sample of c...         01/01/2016
# 81532   2 - Data submitted were based on a sample of c...         01/01/2016
# 9064    2 - Data submitted were based on a sample of c...         01/01/2016
# 81092   2 - Data submitted were based on a sample of c...         01/01/2016
# 80938   2 - Data submitted were based on a sample of c...         01/01/2016
# 63404   2 - Data submitted were based on a sample of c...         01/01/2016
# 10274   2 - Data submitted were based on a sample of c...         01/01/2016
# 81004                                                             01/01/2016
# 63756   2 - Data submitted were based on a sample of c...         01/01/2016
# 21296   2 - Data submitted were based on a sample of c...         01/01/2016
# 81312                                                             01/01/2016
# 81400   2 - Data submitted were based on a sample of c...         01/01/2016
# 16104   2 - Data submitted were based on a sample of c...         01/01/2016
# 81268   2 - Data submitted were based on a sample of c...         01/01/2016
# 63008   2 - Data submitted were based on a sample of c...         01/01/2016
# ...                                                   ...                ...
# 104236  5 - Results are not available for this reporti...         01/01/2016
# 104258  5 - Results are not available for this reporti...         01/01/2016
# 104280  5 - Results are not available for this reporti...         01/01/2016
# 104324  2 - Data submitted were based on a sample of c...         01/01/2016
# 104390  2 - Data submitted were based on a sample of c...         01/01/2016
# 104588  19 - Data are shown only for hospitals that pa...         01/01/2016
# 104610  1 - The number of cases/patients is too few to...         01/01/2016
# 104654  1 - The number of cases/patients is too few to...         01/01/2016
# 104698  1 - The number of cases/patients is too few to...         01/01/2016
# 104764  1 - The number of cases/patients is too few to...         01/01/2016
# 104830  1 - The number of cases/patients is too few to...         01/01/2016
# 104940  2 - Data submitted were based on a sample of c...         01/01/2016
# 104962  5 - Results are not available for this reporti...         01/01/2016
# 104984  1 - The number of cases/patients is too few to...         01/01/2016
# 105270  5 - Results are not available for this reporti...         01/01/2016
# 105324  5 - Results are not available for this reporti...         01/01/2016
# 105368  19 - Data are shown only for hospitals that pa...         01/01/2016
# 105390  5 - Results are not available for this reporti...         01/01/2016
# 105490  19 - Data are shown only for hospitals that pa...         01/01/2016
# 105512  19 - Data are shown only for hospitals that pa...         01/01/2016
# 105622  5 - Results are not available for this reporti...         01/01/2016
# 105666  19 - Data are shown only for hospitals that pa...         01/01/2016
# 105688  1 - The number of cases/patients is too few to...         01/01/2016
# 105710  5 - Results are not available for this reporti...         01/01/2016
# 105732  19 - Data are shown only for hospitals that pa...         01/01/2016
# 105754  1 - The number of cases/patients is too few to...         01/01/2016
# 105776  5 - Results are not available for this reporti...         01/01/2016
# 105798  5 - Results are not available for this reporti...         01/01/2016
# 105820  19 - Data are shown only for hospitals that pa...         01/01/2016
# 105842  5 - Results are not available for this reporti...         01/01/2016
#
#        measure_end_date
# 81158        12/31/2016
# 81202        12/31/2016
# 81488        12/31/2016
# 80982        12/31/2016
# 6512         12/31/2016
# 10054        12/31/2016
# 80894        12/31/2016
# 81290        12/31/2016
# 8998         12/31/2016
# 81708        12/31/2016
# 63294        12/31/2016
# 80872        12/31/2016
# 8800         12/31/2016
# 81642        12/31/2016
# 81180        12/31/2016
# 64042        12/31/2016
# 81532        12/31/2016
# 9064         12/31/2016
# 81092        12/31/2016
# 80938        12/31/2016
# 63404        12/31/2016
# 10274        12/31/2016
# 81004        12/31/2016
# 63756        12/31/2016
# 21296        12/31/2016
# 81312        12/31/2016
# 81400        12/31/2016
# 16104        12/31/2016
# 81268        12/31/2016
# 63008        12/31/2016
# ...                 ...
# 104236       12/31/2016
# 104258       12/31/2016
# 104280       12/31/2016
# 104324       12/31/2016
# 104390       12/31/2016
# 104588       12/31/2016
# 104610       12/31/2016
# 104654       12/31/2016
# 104698       12/31/2016
# 104764       12/31/2016
# 104830       12/31/2016
# 104940       12/31/2016
# 104962       12/31/2016
# 104984       12/31/2016
# 105270       12/31/2016
# 105324       12/31/2016
# 105368       12/31/2016
# 105390       12/31/2016
# 105490       12/31/2016
# 105512       12/31/2016
# 105622       12/31/2016
# 105666       12/31/2016
# 105688       12/31/2016
# 105710       12/31/2016
# 105732       12/31/2016
# 105754       12/31/2016
# 105776       12/31/2016
# 105798       12/31/2016
# 105820       12/31/2016
# 105842       12/31/2016
#
# [4812 rows x 16 columns]

# %% [markdown]
# ### Examining Readmissions

# %% [markdown]
# Let's examine the score of each measure_id in the Readmissions' table

# %%
sb.boxplot(x=readmissions['measure_id'], y=pd.to_numeric(readmissions['score'].replace('Not Available', np.nan)))

# %% [markdown]
# We'll keep the following columns from readmissions
#
# - 'provider_id',
# - 'measure_name',
# - 'measure_id',
# - 'vha_national_rate',
# - 'compare_to_national',
# - 'score'

# %% [markdown]
# ### Conclusion

# %% [markdown]
# We reduced down the amount of columns in each table into the following four tables and the .sql or .py files are in our transform folder
#
# - effective_care_scores
# - hospital_reduced
# - readmissions_reduced
# - survey_responses_reduced
